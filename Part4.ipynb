# %%
import numpy as np
import glob
import scipy.stats as stats
import matplotlib.pyplot as plt
import matplotlib
from datetime import datetime
from collections import Counter
from pylab import *
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap, cm
import mplleaflet

# %%
import mplleaflet
from mpl_toolkits.basemap import Basemap, cm
import MySQLdb
import pandas as pd

lat=34.0211
longi=-118.374

conn=MySQLdb.connect(host="midterm.cygmpyyoxgjg.us-east-1.rds.amazonaws.com",port=3306,user="midterm",passwd="nemesiss",db="midterm")
c=conn.cursor()
c.execute("SELECT *,3956*2*ASIN(SQRT(POWER(SIN((%s-abs(geo.latitude))*pi()/180/2),2)+COS(%s*pi()/180)*COS(abs(geo.latitude)*pi()/180)*POWER(SIN((%s-geo.longitude)*pi()/180 / 2), 2) )) as distance FROM geo having distance < 10 ORDER BY distance limit 10",(lat,lat,longi))
rows=c.fetchall()


if not rows:
    print("no locations found")
else:
    row=pd.DataFrame.from_records(list(rows))
#     print(row.head(5))
    sample = row.sample(10)
    sample_lat=sample[1]
    sample_long=sample[2]
    for eachrow in sample:
        for r in sample:
            plt.scatter(sample_long.values,sample_lat.values)
mplleaflet.display()

# sample = edadata.sample(1000)
# plt.scatter(sample['longitude'], sample['latitude'])

# mplleaflet.display()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="240"></iframe>
